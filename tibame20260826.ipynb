# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahTai/tibame20260826/blob/main/tibame20260826.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 工具>>設定>>編輯器: 字型consolas,縮排4,顯示行數v,顯示縮排v
# - 每個區塊獨立，但上下有關聯
# - 文字區塊: markown語法、Latex Math語法
# - Latex Math語法: \ {}
#
# $ area = \frac{1}{1+x} \pi R $

# %%
a=3
print(a)
# Out:
# 3

# %%
print(a+2)
# Out:
# 5
