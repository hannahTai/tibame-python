# %% [markdown]
# <a href="https://colab.research.google.com/github/hannahTai/tibame-python/blob/main/tibame20260826.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 工具>>設定>>編輯器: 字型consolas,縮排4,顯示行數v,顯示縮排v
# - 程式碼區塊: 每個區塊獨立，但上下有關聯
# - 文字區塊: markown語法、Latex Math語法
# - Latex Math語法: \ {}
#     - $ area = \frac{1}{1+x} \pi R^3 $

# %% [markdown]
# # LAB 1. 完全平方日
#
# - 完全平方日: 日期 yyyymmdd 是某數的平方
# - 題目: 給你一個日期，你要往後數出接下來的10個完全平方日的日期
# - 以後只要看到有^2 ^3 ^4..., 都應該使用原數字處理
# - 閏年概念:
# $365+\frac{1}{4}-\frac{1}{100}+\frac{1}{400} - ...$

# %%
# 閏年判斷1
# 1963: X
# 1964: O
# 1800: X
# 2000: O

year = 2000
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print(year, ": O")
        else:
            print(year, ": X")
    else:
        print(year, ": O")
else:
    print(year, ": X")
# Out:
# 2000 : O

# %%
# 閏年判斷2(suggested)
# 1963: X
# 1964: O
# 1800: X
# 2000: O

year = 2000
if year % 400 == 0:
    print(year, ": O")
elif year % 100 == 0:
    print(year, ": X")
elif year % 4 == 0:
    print(year, ": O")
else:
    print(year, ": X")
# Out:
# 2000 : O

# %%
# 閏年判斷3
# 從某年找十個閏年
start = 1992
count = 0
i = 0
while True:
    year = start + i
    if year % 4 == 0 and ((year % 100 != 0) or (year % 100 == 0 and year % 400 == 0)):
        print(year, ": 0")
        count +=1
    if(count >=10):
        break;
    i += 1
# Out:
# 1992 : 0
# 1996 : 0
# 2000 : 0
# 2004 : 0
# 2008 : 0
# 2012 : 0
# 2016 : 0
# 2020 : 0
# 2024 : 0
# 2028 : 0

# %%
# 想法二
count = 0
x = 20100101
i = int(x**0.5) + 1
while True:
    dateNum = i * i
    dateStr = str(i * i)
    year = dateStr[0:4]
    month = dateStr[4:6]
    day = dateStr[6:8]
    print(dateStr)
    print(year)
    print(month)
    print(day)
    if year < 1:
        break;
    if month <

    if count == 10:
        break;
    i += 1
# Out:
# 20106256
# 2010
# 62
# 56
# 20115225
# 2011
# 52
# 25
# 20124196
# 2012
# 41
# 96
# 20133169
# 2013
# 31
# 69
# 20142144
# 2014
# 21
# 44
# 20151121
# 2015
# 11
# 21
# 20160100
# 2016
# 01
# 00
# 20169081
# 2016
# 90
# 81
# 20178064
# 2017
# 80
# 64
# 20187049
# 2018
# 70
# 49
# 20196036
# 2019
# 60
# 36
# 20205025
# 2020
# 50
# 25
